# %% [markdown]
# <a href="https://colab.research.google.com/github/logblackstone/School/blob/main/Module3Project_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
url = 'https://btech-data-analytics.github.io/bridgerland-technical-college/bookstore.html'
soup = BeautifulSoup(requests.get(url).text, 'html.parser')
table = soup.find('table')

# %%
soup.find_all('tr')
soup.find_all('td')
table = soup.find('table')

headers = [header.text.strip() for header in table.find_all('th')]

rows = []
for row in table.find_all('tr')[1:]:
    cells = row.find_all('td')
    rows.append([cell.text.strip() for cell in cells])

# df = pd.DataFrame(rows, columns=headers)
# display(df)

author_counts = df['Author'].value_counts()
print(author_counts.idxmax(), author_counts.max())
topic_counts = df['Topic'].value_counts()
print(topic_counts.idxmax(), topic_counts.max())
# Out:
# Penelope Wainwright 4
# Cats 10

# %%
print(df.groupby('Topic')['Price'].mean().idxmax(), df.groupby('Topic')['Price'].mean().max())
df['Pages'] = df['Pages'].astype(int)
print(df.groupby('Topic')['Pages'].mean().idxmax(), df.groupby('Topic')['Pages'].mean().max())
# Out:
# Dogs 256.0
